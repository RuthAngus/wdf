# %%
import numpy as np
import pandas as pd
from astropy.io import fits
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# In order to create GUMS_small.csv I downloaded a tsv with 9999 values and swapped ";" for "," and deleted all spaces. I then deleted the line of "----" and swapped the row of units with the row of column headers.

# %%
df = pd.read_csv("data/GUMS_small.csv", skiprows=90)
df
# Out:
#          recno                  ID     RA2kdeg    DE2kdeg  Pop    VMAG  \
# 0   1330558561   *200322997-000001   63.156438 -89.969049    1  10.300
# 1   1330558562  *200322999-000002+    3.790924 -89.992985    1   5.596
# 2   1330558563  *200322999-000002A    3.791814 -89.992985    1   5.600
# 3   1330558564  *200322999-000002B    3.788488 -89.992985    1  11.500
# 4   1330558565   *200323004-000002   29.970911 -89.971533    1   0.700
# 5   1330558566  *200322997-000006+   45.398095 -89.974120    2   3.600
# 6   1330558567  *200322997-000006A   45.398095 -89.974120    2   3.600
# 7   1330558568  E200322997-000006B   45.398017 -89.974120    2  32.580
# 8   1330558569   *200322997-000007   68.430692 -89.973678    2   3.800
# 9   1330558574  *200322954-000004+   80.768338 -89.971794    1   5.500
# 10  1330558575  *200322954-000004A   80.768338 -89.971794    1   5.500
# 11  1330558576  E200322954-000004B   80.768396 -89.971794    1  32.580
# ...
